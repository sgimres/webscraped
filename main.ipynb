# %%
import pandas as pd

# %%
df = pd.read_csv('products.csv')

# %%
df.shape
# Out:
# (865, 5)

# %%
df.head()
# Out:
#                                                title  \
# 0  Casual Blouse Loose Men's Shirt Cotton Linen F...
# 1  Anationz – Linen Cotton Normal Collar Shirt – ...
# 2  *Biutiful Factory Store*OIMG Canvas Belt Men T...
# 3  Two Points Sling Bungee Shoulder Strap Durable...
# 4            Mens Comfy Cotton Vest -RN 9058 (Ebony)
#
#                                                 link discounted_price  \
# 0  https://www.daraz.lk/products/casual-blouse-lo...         Rs.3,409
# 1  https://www.daraz.lk/products/anationz-linen-c...         Rs.4,230
# 2  https://www.daraz.lk/products/biutiful-factory...         Rs.3,006
# 3  https://www.daraz.lk/products/two-points-sling...         Rs.1,556
# 4  https://www.daraz.lk/products/mens-comfy-cotto...           Rs.830
#
#       original_price                                          image_url
# 0          Rs.13,110  https://img.drz.lazcdn.com/g/kf/Sde3d86a3d6714...
# 1           Rs.5,640  https://img.drz.lazcdn.com/g/kf/S0966bd4fef0d4...
# ...
